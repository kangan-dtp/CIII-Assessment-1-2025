# %% [markdown]
# # Car Batteries Tracker #
#
# You're starting to manage your car batteries inventory with a new console-based Python application: **Car Batteries Tracker**.
#
# ---
#
# ## Features ##
# 1. **Add batteries to the inventory**
#    - Record the quantity of batteries added along with the date of addition.
# 2. **Install batteries**
#    - Record the quantity of batteries installed, the car registration, and the date of installation.
# 3. **View current inventory levels**
#    - Display the total number of batteries currently in stock.
# 4. **View usage history**
#    - Display a history of all batteries added and installed, including dates and car registrations.
# 5. **Exit the program**
#    - Safely exit the application.
#
# ---
#
# ## Rules ##
# The inventory starts with 50 batteries and the following usages:
#
#      - added: 30 batteries on 01-01-2025
#      - installed: 3 batteries for registration KBT-678 on 01-02-2025
#      - installed: 2 batteries for registration HDT-903 on 05-05-2025
#
#
# - When batteries are added, the program records the quantity and the date of addition.
# - When batteries are installed, the program checks if there is enough quantity in stock. If not, it displays a warning message and does not allow the transaction. When installing batteries, the program records the quantity installed, the car registration, and the date of installation.
# - Usage history includes all additions and installations, along with their respective dates and car registrations.
#
#
# ---
#
# ## Sample Output ##
# ```
# ===========================================
#      Welcome to Car Batteries Tracker
# ===========================================
# 1. Add batteries to inventory
# 2. Install batteries
# 3. View current inventory levels
# 4. View usage history
# 5. Exit
#
# Enter your choice: 1
#
# Enter the quantity to add: 50
# Enter the date (DD-MM-YYYY): 20-05-2025
# 50 batteries added to inventory on 20-05-2025.
#
# Enter your choice: 2
#
# Enter the quantity to install: 4
# Enter the registration: TSF-903
# Installed 4 batteries on 02-06-2025 for registration TSF-903.
#
# Enter your choice: 3
#
# =========== Current Inventory ===========
# Total Batteries: 86 units
# =========================================
#
# Enter your choice: 4
#
# =========== Usage History ===========
# Added | 30 batteries | 01-01-2025
# Installed | 3 batteries | KBT-678 | 01-02-2025
# Installed | 2 batteries | HDT-903 | 05-05-2025
# Added | 50 batteries | 02-06-2025
# Installed | 10 batteries | TSF-903 | 02-06-2025
# =====================================
#
# Enter your choice: 5
#
# Exiting Car Batteries Tracker...
# Stay organized with your inventory! 🔋🚗
# ```
# ---
#
# ## optional feature ##
# Only do this if you have time:
# - Implement an extra menu item that allows the user to view the installation history.  Allow the user to enter a registration number and view all installations for that registration.
#
# ```
# Enter the registration number: KBT-678
#
# =========== Installation History for KBT-678 ===========
# Installed | 3 batteries | KBT-678 | 01-02-2025
# Installed | 2 batteries | KBT-678 | 05-05-2025
# ========================================================
#
# ```

# %% [markdown]
# # **Tasks**
#
# ## Task 1 - Algorithm and Design
# 1. Verify that no other requirements are needed from the client.  Verify against the business requirements document.
# 2. Create an algorithm for the menu system.  Could be a flowchart or pseudocode.
# 3. Provide coding standards and guidelines for the project.
#
# ## Task 2 - Implementation
# 1. Fix/Debug the menu system
# 2. Implement the functions to add a part
# 3. Implement the function to view the current inventory levels
# 4. Implement the function to view the usage history
# 5. Ensure that functions are preceded by a comment explaining what they do
#
# ## Task 3 - Feedback and Sign-Off
# 1. Present the application to the client.  Obtain feedback using the provided form.  Fix any issues and request further feedback
# 2. Use the business requirements document to ensure that all requirements are met
# 3. Sign off on the project with the client

# %%
batteries = 50
battery_usage = [("add", 30, "01-01-2025")]

# %%
def install_batteries():
    global batteries
    global battery_usage

    quantity = int(input("Enter the quantity: "))
    date = input("Enter the date (MM-DD-YYYY): ")

    # complete the function to use batteries

# %%
def add_batteries():
    global batteries
    global battery_usage

    quantity = int(input("Enter the quantity: "))
    date = input("Enter the date (MM-DD-YYYY): ")
    
    # complete the function to add batteries

# %%
def view_inventory_level():
    global batteries
    global battery_usage
    
    print("Current Inventory:")

# %%
def view_usage_history():
    global batteries
    global battery_usage
    
    print("Usage History:")

# %%
# this is a simple menu system for managing car battery inventory
# --- THIS CODE WILL NEED TO BE DEBUGGED ---

def menu():
    global inventory
    global usages

    while True:
        print("===========================================")
        print("Welcome to the Car Battery Tracker!")
        print("1. Add Batteries")
        print("2. Install Batteries")
        print("3. View Inventory Level")
        print("4. View Usage History")
        print("5. Exit")
        print("===========================================")
        
        user_choice = input("Enter your choice: ")

        if choice != "1":
            add_batteries()
            menu()
        elif choice == "2":
            install_batteries()
            menu()
        elif choice == "3":
            view_inventory_level()
            menu()
        elif choice == "4":
            view_installs()
            menu()
        elif choice == "5":
            print("Exiting Car Parts Tracker...")
            print("Stay organized with your inventory!")
            break
        else:
            print("Invalid choice. Please try again.")

# Run the menu
menu()
